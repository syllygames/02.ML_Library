# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option("display.max_columns", 10)
# pd.reset_option("display.max_columns")
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
filePath = "D:\\01\\Machine_Learning_DineshKumar_book\\Data\\IPL IMB381IPL2013.csv"
df_ipl = pd.read_csv(filePath)
df_ipl.head().transpose()
# Out:
#                          0             1            2          3             4
# Sl.NO.                   1             2            3          4             5
# PLAYER NAME    Abdulla, YA  Abdur Razzak  Agarkar, AB  Ashwin, R  Badrinath, S
# AGE                      2             2            2          1             2
# COUNTRY                 SA           BAN          IND        IND           IND
# TEAM                  KXIP           RCB          KKR        CSK           CSK
# PLAYING ROLE    Allrounder        Bowler       Bowler     Bowler       Batsman
# T-RUNS                   0           214          571        284            63
# T-WKTS                   0            18           58         31             0
# ODI-RUNS-S               0           657         1269        241            79
# ODI-SR-B               0.0         71.41        80.62      84.56         45.93
# ODI-WKTS                 0           185          288         51             0
# ...

# %%
df_ipl.info()
df_ipl.count()
df_ipl.dtypes
df_ipl.nunique()
df_ipl["AUCTION YEAR"].nunique()
df_ipl["AUCTION YEAR"].unique()
df_ipl["AUCTION YEAR"].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
df_ipl["AUCTION YEAR"].is_unique
mask1 = df_ipl["AUCTION YEAR"].isna()
df_ipl[mask1]
mask2 = df_ipl["AUCTION YEAR"].notna()
df_ipl[mask2]
# Out:
# False
# Empty DataFrame
# Columns: [Sl.NO., PLAYER NAME, AGE, COUNTRY, TEAM, PLAYING ROLE, T-RUNS, T-WKTS, ODI-RUNS-S, ODI-SR-B, ODI-WKTS, ODI-SR-BL, CAPTAINCY EXP, RUNS-S, HS, AVE, SR-B, SIXERS, RUNS-C, WKTS, AVE-BL, ECON, SR-BL, AUCTION YEAR, BASE PRICE, SOLD PRICE]
# Index: []
#
# [0 rows x 26 columns]
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM  ...   ECON  SR-BL  \
# 0         1   Abdulla, YA    2      SA   KXIP  ...   8.90  13.93
# 1         2  Abdur Razzak    2     BAN    RCB  ...  14.50   0.00
# 2         3   Agarkar, AB    2     IND    KKR  ...   8.81  24.90
# 3         4     Ashwin, R    1     IND    CSK  ...   6.23  22.14
# 4         5  Badrinath, S    2     IND    CSK  ...   0.00   0.00
# ..      ...           ...  ...     ...    ...  ...    ...    ...
# 125     126     Yadav, AS    2     IND     DC  ...   0.00   0.00
# 126     127   Younis Khan    2     PAK     RR  ...   0.00   0.00
# 127     128  Yuvraj Singh    2     IND  KXIP+  ...   7.02  21.13
# ...

# %%
df_ipl.axes
df_ipl.index
df_ipl.columns
# Out:
# [RangeIndex(start=0, stop=130, step=1),
#  Index(['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE',
#         'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#         'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#         'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#         'SOLD PRICE'],
#        dtype='object')]
# RangeIndex(start=0, stop=130, step=1)
# Index(['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE',
#        'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE'],
#       dtype='object')

# %%
df_ipl.shape
df_ipl.ndim
df_ipl.size
# Out:
# (130, 26)
# 2
# 3380

# %%
type(df_ipl.columns)
type(df_ipl.columns.to_list())
type(df_ipl.columns.tolist())
type(list(df_ipl.columns))
# Out:
# pandas.core.indexes.base.Index
# list
# list
# list

# %% [markdown]
# ## convert datatype to required
# ### ??mixed datatype in single column

# %%
df_ipl.dtypes 
# select_dtypes
# convert_dtypes
# astype
# Out:
# Sl.NO.             int64
# PLAYER NAME       object
# AGE                int64
# COUNTRY           object
# TEAM              object
# PLAYING ROLE      object
# T-RUNS             int64
# T-WKTS             int64
# ODI-RUNS-S         int64
# ODI-SR-B         float64
# ODI-WKTS           int64
# ODI-SR-BL        float64
# CAPTAINCY EXP      int64
# RUNS-S             int64
# HS                 int64
# AVE              float64
# SR-B             float64
# SIXERS             int64
# RUNS-C             int64
# WKTS               int64
# AVE-BL           float64
# ECON             float64
# SR-BL            float64
# AUCTION YEAR       int64
# BASE PRICE         int64
# SOLD PRICE         int64
# dtype: object

# %%
df_ipl.nunique()
df_ipl.count()
df_ipl.nunique() / df_ipl.count()
# Out:
# Sl.NO.           130
# PLAYER NAME      130
# AGE                3
# COUNTRY           10
# TEAM              17
# PLAYING ROLE       4
# T-RUNS           103
# T-WKTS            60
# ODI-RUNS-S       117
# ODI-SR-B         118
# ODI-WKTS          74
# ODI-SR-BL         82
# CAPTAINCY EXP      2
# RUNS-S           115
# HS                73
# AVE              113
# SR-B             125
# SIXERS            48
# RUNS-C            92
# WKTS              51
# AVE-BL            88
# ECON              83
# SR-BL             82
# AUCTION YEAR       4
# BASE PRICE        17
# SOLD PRICE        53
# dtype: int64
# Sl.NO.           130
# PLAYER NAME      130
# AGE              130
# COUNTRY          130
# TEAM             130
# PLAYING ROLE     130
# T-RUNS           130
# T-WKTS           130
# ODI-RUNS-S       130
# ODI-SR-B         130
# ODI-WKTS         130
# ODI-SR-BL        130
# CAPTAINCY EXP    130
# RUNS-S           130
# HS               130
# AVE              130
# ...

# %%
df_ipl.nunique().plot(kind= "bar")
# Out:
# <AxesSubplot:>

# %%
(df_ipl.nunique()/df_ipl.count() ) .plot(kind= "bar")
# Out:
# <AxesSubplot:>

# %%
df_ipl["AGE"].value_counts().plot(kind= "bar")
# df_ipl["AGE"].value_counts(normalize = False).plot.bar(title = 'Loan_Status')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(df_ipl["AGE"])
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='count'>

# %% [markdown]
# # identify categorical and numberical columns

# %%
# manipulating and transforming column names
# df.columns.str.strip().str.lower().str.replace(" ", "_")

# %%
# flatten column names in groupby agg or in pivot agg

# [" ".join(each_col).strip().replace(" ","_") for each_col in df2.columns  ]

# %%
df_ipl.dtypes.value_counts()
df_ipl.info()
# Out:
# int64      15
# float64     7
# object      4
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
# ...

# %%
df_ipl.select_dtypes(include = [object]).nunique()
df_ipl.select_dtypes(include = [object]).nunique().keys().to_list()
# Out:
# PLAYER NAME     130
# COUNTRY          10
# TEAM             17
# PLAYING ROLE      4
# dtype: int64
# ['PLAYER NAME', 'COUNTRY', 'TEAM', 'PLAYING ROLE']

# %%
# df_ipl.describe().T
df_ipl.describe().transpose()
df_ipl.describe().transpose().shape
# Out:
#                count           mean            std      min          25%  \
# Sl.NO.         130.0      65.500000      37.671829      1.0      33.2500
# AGE            130.0       2.092308       0.576627      1.0       2.0000
# T-RUNS         130.0    2166.715385    3305.646757      0.0      25.5000
# T-WKTS         130.0      66.530769     142.676855      0.0       0.0000
# ODI-RUNS-S     130.0    2508.738462    3582.205625      0.0      73.2500
# ODI-SR-B       130.0      71.164385      25.898440      0.0      65.6500
# ODI-WKTS       130.0      76.076923     111.205070      0.0       0.0000
# ODI-SR-BL      130.0      34.033846      26.751749      0.0       0.0000
# CAPTAINCY EXP  130.0       0.315385       0.466466      0.0       0.0000
# RUNS-S         130.0     514.246154     615.226335      0.0      39.0000
# HS             130.0      47.430769      36.403624      0.0      16.0000
# AVE            130.0      18.719308      11.094224      0.0       9.8250
# ...

# %%
# autos["horsepower"] = pd.to_numeric(autos["horsepower"], errors ="coerce")
# autos.dropna(subset = ["horsepower"], inplace = True)

# %%
col_numerical = df_ipl.describe().columns.to_list()
col_numerical
col_categorical = [col for col in df_ipl.columns.to_list() if col not in col_numerical]
col_categorical
# Out:
# ['Sl.NO.',
#  'AGE',
#  'T-RUNS',
#  'T-WKTS',
#  'ODI-RUNS-S',
#  'ODI-SR-B',
#  'ODI-WKTS',
#  'ODI-SR-BL',
#  'CAPTAINCY EXP',
#  'RUNS-S',
#  'HS',
#  'AVE',
#  'SR-B',
#  'SIXERS',
#  'RUNS-C',
#  'WKTS',
#  'AVE-BL',
#  'ECON',
#  'SR-BL',
#  'AUCTION YEAR',
#  'BASE PRICE',
#  'SOLD PRICE']
# ['PLAYER NAME', 'COUNTRY', 'TEAM', 'PLAYING ROLE']

# %%
df_ipl.describe().T
# Out:
#                count           mean            std      min          25%  \
# Sl.NO.         130.0      65.500000      37.671829      1.0      33.2500
# AGE            130.0       2.092308       0.576627      1.0       2.0000
# T-RUNS         130.0    2166.715385    3305.646757      0.0      25.5000
# T-WKTS         130.0      66.530769     142.676855      0.0       0.0000
# ODI-RUNS-S     130.0    2508.738462    3582.205625      0.0      73.2500
# ODI-SR-B       130.0      71.164385      25.898440      0.0      65.6500
# ODI-WKTS       130.0      76.076923     111.205070      0.0       0.0000
# ODI-SR-BL      130.0      34.033846      26.751749      0.0       0.0000
# CAPTAINCY EXP  130.0       0.315385       0.466466      0.0       0.0000
# RUNS-S         130.0     514.246154     615.226335      0.0      39.0000
# HS             130.0      47.430769      36.403624      0.0      16.0000
# AVE            130.0      18.719308      11.094224      0.0       9.8250
# ...

# %%
df_ipl[col_categorical].describe()
# Out:
#         PLAYER NAME COUNTRY TEAM PLAYING ROLE
# count           130     130  130          130
# unique          130      10   17            4
# top     Abdulla, YA     IND  CSK       Bowler
# freq              1      53   14           44

# %%
df_ipl[col_numerical].describe().T
# Out:
#                count           mean            std      min          25%  \
# Sl.NO.         130.0      65.500000      37.671829      1.0      33.2500
# AGE            130.0       2.092308       0.576627      1.0       2.0000
# T-RUNS         130.0    2166.715385    3305.646757      0.0      25.5000
# T-WKTS         130.0      66.530769     142.676855      0.0       0.0000
# ODI-RUNS-S     130.0    2508.738462    3582.205625      0.0      73.2500
# ODI-SR-B       130.0      71.164385      25.898440      0.0      65.6500
# ODI-WKTS       130.0      76.076923     111.205070      0.0       0.0000
# ODI-SR-BL      130.0      34.033846      26.751749      0.0       0.0000
# CAPTAINCY EXP  130.0       0.315385       0.466466      0.0       0.0000
# RUNS-S         130.0     514.246154     615.226335      0.0      39.0000
# HS             130.0      47.430769      36.403624      0.0      16.0000
# AVE            130.0      18.719308      11.094224      0.0       9.8250
# ...

# %% [markdown]
# ## test case

# %%
st1 = 'abcdefghijklmnop'
fname_1 = [s for s in st1]
lname_1 = [s+"_last" for s in st1]
age_1 = list( range(41,57) )
rank_1 = list(range(1,len(s1) +1) )

# %%
age_2_str = [str(s) for s in age_1]
age_2_str[2] = "test_1"
age_2_str[4] = "test_2"
age_2_str[6] = "test_3"
age_2_str[8] = ""

# %%
dict_1 = {'fname':fname_1, "lname":lname_1, 'age':age_2_str, 'rank': rank_1}
df_test = pd.DataFrame(dict_1)

# %%
df_test

# %%
df_test.info()

# %%
# df_test["age"] = pd.to_numeric(df_test["age"], errors ="coerce")
# df_test.dropna(subset = ["age"], inplace = True)

# %%
series_1 =pd.to_numeric(df_test["age"], errors ="coerce")
series_1

# %%
type(series_1[8])
series_1[8]

# %%
df_test["age"] = pd.to_numeric(df_test["age"], errors ="coerce")

# %%
df_test.info()
