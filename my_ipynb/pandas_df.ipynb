# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option("display.max_columns", 10)
# pd.reset_option("display.max_columns")

# %%
filePath = "D:\\01\\Machine_Learning_DineshKumar_book\\Data\\IPL IMB381IPL2013.csv"

# %%
df = pd.read_csv(filePath)
df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM  ...   ECON  SR-BL  AUCTION YEAR  \
# 0       1   Abdulla, YA    2      SA  KXIP  ...   8.90  13.93          2009
# 1       2  Abdur Razzak    2     BAN   RCB  ...  14.50   0.00          2008
# 2       3   Agarkar, AB    2     IND   KKR  ...   8.81  24.90          2008
# 3       4     Ashwin, R    1     IND   CSK  ...   6.23  22.14          2011
# 4       5  Badrinath, S    2     IND   CSK  ...   0.00   0.00          2011
#
#    BASE PRICE  SOLD PRICE
# 0       50000       50000
# 1       50000       50000
# 2      200000      350000
# 3      100000      850000
# 4      100000      800000
#
# [5 rows x 26 columns]

# %% [markdown]
# ## summary

# %%
df.ndim
df.shape
df.axes
len(df.axes)
df.index
df.columns
# Out:
# 2
# (130, 26)
# [RangeIndex(start=0, stop=130, step=1),
#  Index(['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE',
#         'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#         'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#         'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#         'SOLD PRICE'],
#        dtype='object')]
# 2
# RangeIndex(start=0, stop=130, step=1)
# Index(['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE',
#        'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE'],
#       dtype='object')

# %%
df.describe()
df.describe().transpose()
# Out:
#            Sl.NO.         AGE        T-RUNS      T-WKTS    ODI-RUNS-S  ...  \
# count  130.000000  130.000000    130.000000  130.000000    130.000000  ...
# mean    65.500000    2.092308   2166.715385   66.530769   2508.738462  ...
# std     37.671829    0.576627   3305.646757  142.676855   3582.205625  ...
# min      1.000000    1.000000      0.000000    0.000000      0.000000  ...
# 25%     33.250000    2.000000     25.500000    0.000000     73.250000  ...
# 50%     65.500000    2.000000    542.500000    7.000000    835.000000  ...
# 75%     97.750000    2.000000   3002.250000   47.500000   3523.500000  ...
# max    130.000000    3.000000  15470.000000  800.000000  18426.000000  ...
#
#              ECON       SR-BL  AUCTION YEAR    BASE PRICE    SOLD PRICE
# count  130.000000  130.000000    130.000000  1.300000e+02  1.300000e+02
# mean     6.204462   17.382615   2009.092308  1.922308e+05  5.212231e+05
# std      4.941531   15.273422      1.377821  1.530973e+05  4.068074e+05
# ...

# %%
# df.select_dtypes(include = 'object')
df.info()
df.dtypes
df.count()
df.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
df["AGE"].value_counts(normalize = True)
df["AGE"].value_counts(normalize = True).plot.bar(title = 'Loan_Status')
# Out:
# 2    0.661538
# 3    0.215385
# 1    0.123077
# Name: AGE, dtype: float64
# <AxesSubplot:title={'center':'Loan_Status'}>

# %%
df["AGE"].nunique()
df["AGE"].unique()
df["AGE"].value_counts()
# Out:
# 3
# array([2, 1, 3], dtype=int64)
# 2    86
# 3    28
# 1    16
# Name: AGE, dtype: int64

# %%
df.columns = df.columns.str.upper().str.replace(" ", "_")

# %%
df[:4]
df.tail()
# Out:
#    SL.NO.   PLAYER_NAME  AGE COUNTRY  TEAM  ...   ECON  SR-BL  AUCTION_YEAR  \
# 0       1   Abdulla, YA    2      SA  KXIP  ...   8.90  13.93          2009
# 1       2  Abdur Razzak    2     BAN   RCB  ...  14.50   0.00          2008
# 2       3   Agarkar, AB    2     IND   KKR  ...   8.81  24.90          2008
# 3       4     Ashwin, R    1     IND   CSK  ...   6.23  22.14          2011
#
#    BASE_PRICE  SOLD_PRICE
# 0       50000       50000
# 1       50000       50000
# 2      200000      350000
# 3      100000      850000
#
# [4 rows x 26 columns]
#      SL.NO.   PLAYER_NAME  AGE COUNTRY   TEAM  ...  ECON  SR-BL  AUCTION_YEAR  \
# 125     126     Yadav, AS    2     IND     DC  ...  0.00   0.00          2010
# 126     127   Younis Khan    2     PAK     RR  ...  0.00   0.00          2008
# 127     128  Yuvraj Singh    2     IND  KXIP+  ...  7.02  21.13          2011
# 128     129   Zaheer Khan    2     IND    MI+  ...  7.75  21.26          2008
# ...

# %%
df[ ["AGE", "PLAYER_NAME", "BASE_PRICE","SOLD_PRICE" ] ][0:5]
# Out:
#    AGE   PLAYER_NAME  BASE_PRICE  SOLD_PRICE
# 0    2   Abdulla, YA       50000       50000
# 1    2  Abdur Razzak       50000       50000
# 2    2   Agarkar, AB      200000      350000
# 3    1     Ashwin, R      100000      850000
# 4    2  Badrinath, S      100000      800000

# %%
df.iloc[[1,7,8], [5,5]]
df.iloc[[1,4,2],1:5]
# Out:
#   PLAYING_ROLE PLAYING_ROLE
# 1       Bowler       Bowler
# 7       Bowler       Bowler
# 8   Allrounder   Allrounder
#     PLAYER_NAME  AGE COUNTRY TEAM
# 1  Abdur Razzak    2     BAN  RCB
# 4  Badrinath, S    2     IND  CSK
# 2   Agarkar, AB    2     IND  KKR

# %%
pd.crosstab(df["AGE"], df [df.columns[3]])
# Out:
# COUNTRY  AUS  BAN  ENG  IND  NZ  PAK  SA  SL  WI  ZIM
# AGE
# 1          2    0    0   13   0    0   0   1   0    0
# 2         10    1    3   35   5    7  11   8   5    1
# 3         10    0    0    5   2    2   5   3   1    0

# %%
df[["PLAYER_NAME", "SOLD_PRICE"]].sort_values("SOLD_PRICE")
# Out:
#        PLAYER_NAME  SOLD_PRICE
# 73      Noffke, AA       20000
# 46     Kamran Khan       24000
# 0      Abdulla, YA       50000
# 1     Abdur Razzak       50000
# 118  Van der Merwe       50000
# ..             ...         ...
# 113     Tiwary, SS     1600000
# 111  Tendulkar, SR     1800000
# 50        Kohli, V     1800000
# 93       Sehwag, V     1800000
# 127   Yuvraj Singh     1800000
#
# [130 rows x 2 columns]

# %%
df.head()
df["PREMIUM"] = df["SOLD_PRICE"]- df["BASE_PRICE"]
# Out:
#    SL.NO.   PLAYER_NAME  AGE COUNTRY  TEAM  ...   ECON  SR-BL  AUCTION_YEAR  \
# 0       1   Abdulla, YA    2      SA  KXIP  ...   8.90  13.93          2009
# 1       2  Abdur Razzak    2     BAN   RCB  ...  14.50   0.00          2008
# 2       3   Agarkar, AB    2     IND   KKR  ...   8.81  24.90          2008
# 3       4     Ashwin, R    1     IND   CSK  ...   6.23  22.14          2011
# 4       5  Badrinath, S    2     IND   CSK  ...   0.00   0.00          2011
#
#    BASE_PRICE  SOLD_PRICE
# 0       50000       50000
# 1       50000       50000
# 2      200000      350000
# 3      100000      850000
# 4      100000      800000
#
# [5 rows x 26 columns]

# %%
df.iloc[:, [1, -3,-2, -1]].sort_values("PREMIUM", ascending = False)
# Out:
#        PLAYER_NAME  BASE_PRICE  SOLD_PRICE  PREMIUM
# 50        Kohli, V      150000     1800000  1650000
# 113     Tiwary, SS      100000     1600000  1500000
# 127   Yuvraj Singh      400000     1800000  1400000
# 111  Tendulkar, SR      400000     1800000  1400000
# 93       Sehwag, V      400000     1800000  1400000
# ..             ...         ...         ...      ...
# 102      Smith, DR      100000      100000        0
# 73      Noffke, AA       20000       20000        0
# 100     Silva, LPC      100000      100000        0
# 74        Ntini, M      200000      200000        0
# 0      Abdulla, YA       50000       50000        0
#
# [130 rows x 4 columns]

# %%
group_age = df.groupby("AGE")

# %%
type(group_age["SOLD_PRICE"].mean())
type(group_age["SOLD_PRICE"].mean().reset_index())
# Out:
# pandas.core.series.Series
# pandas.core.frame.DataFrame

# %%
group_age["SOLD_PRICE"].mean()
# Out:
# AGE
# 1    720250.000000
# 2    484534.883721
# 3    520178.571429
# Name: SOLD_PRICE, dtype: float64

# %%
group_age["SOLD_PRICE"].mean().reset_index()
# Out:
#    AGE     SOLD_PRICE
# 0    1  720250.000000
# 1    2  484534.883721
# 2    3  520178.571429

# %%
group_age.groups
group_age.agg(["mean", "count", "sum"])
# Out:
# {1: [3, 12, 34, 39, 46, 50, 51, 59, 65, 76, 88, 95, 97, 113, 114, 123], 2: [0, 1, 2, 4, 5, 6, 7, 8, 9, 10, 13, 14, 15, 16, 17, 19, 20, 21, 23, 24, 26, 29, 30, 31, 36, 37, 40, 42, 43, 45, 47, 48, 55, 56, 57, 58, 60, 61, 64, 66, 67, 68, 71, 72, 73, 74, 75, 77, 78, 79, 80, 81, 82, 83, 85, 87, 89, 90, 91, 92, 93, 94, 96, 99, 100, 101, 102, 103, 104, 105, 106, 109, 110, 112, 115, 116, 118, 119, 120, 121, 124, 125, 126, 127, 128, 129], 3: [11, 18, 22, 25, 27, 28, 32, 33, 35, 38, 41, 44, 49, 52, 53, 54, 62, 63, 69, 70, 84, 86, 98, 107, 108, 111, 117, 122]}
#         SL.NO.                   T-RUNS        ... SOLD_PRICE            \
#           mean count   sum         mean count  ...      count       sum
# AGE                                            ...
# 1    67.562500    16  1081   247.687500    16  ...         16  11524000
# 2    66.825581    86  5747  1538.662791    86  ...         86  41670000
# 3    60.250000    28  1687  5192.321429    28  ...         28  14565000
#
# ...

# %%
df2 = group_age["SOLD_PRICE"].mean().reset_index()

# %%
df.merge(df2, how = "outer", on ="AGE").head().transpose()
# Out:
#                            0              1              2              3  \
# SL.NO.                     1              2              3              5
# PLAYER_NAME      Abdulla, YA   Abdur Razzak    Agarkar, AB   Badrinath, S
# AGE                        2              2              2              2
# COUNTRY                   SA            BAN            IND            IND
# TEAM                    KXIP            RCB            KKR            CSK
# PLAYING_ROLE      Allrounder         Bowler         Bowler        Batsman
# T-RUNS                     0            214            571             63
# T-WKTS                     0             18             58              0
# ODI-RUNS-S                 0            657           1269             79
# ODI-SR-B                 0.0          71.41          80.62          45.93
# ODI-WKTS                   0            185            288              0
# ODI-SR-BL                0.0           37.6           32.9            0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SL.NO.         130 non-null    int64
#  1   PLAYER_NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING_ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY_EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
df.head()
# Out:
#    SL.NO.   PLAYER_NAME  AGE COUNTRY  TEAM  ...  SR-BL  AUCTION_YEAR  \
# 0       1   Abdulla, YA    2      SA  KXIP  ...  13.93          2009
# 1       2  Abdur Razzak    2     BAN   RCB  ...   0.00          2008
# 2       3   Agarkar, AB    2     IND   KKR  ...  24.90          2008
# 3       4     Ashwin, R    1     IND   CSK  ...  22.14          2011
# 4       5  Badrinath, S    2     IND   CSK  ...   0.00          2011
#
#    BASE_PRICE  SOLD_PRICE  PREMIUM
# 0       50000       50000        0
# 1       50000       50000        0
# 2      200000      350000   150000
# 3      100000      850000   750000
# 4      100000      800000   700000
#
# [5 rows x 27 columns]

# %%
[col for col in df.columns.tolist() if col not in df.describe().columns.tolist()]
# Out:
# ['PLAYER_NAME', 'COUNTRY', 'TEAM', 'PLAYING_ROLE']

# %%
df.rank()
# Out:
#      SL.NO.  PLAYER_NAME   AGE  COUNTRY   TEAM  ...  SR-BL  AUCTION_YEAR  \
# 0       1.0          1.0  59.5    103.5   73.0  ...   49.0          80.5
# 1       2.0          2.0  59.5     23.0   99.0  ...   21.0          38.0
# 2       3.0          3.0  59.5     53.0   55.0  ...   93.0          38.0
# 3       4.0          4.0   8.5     53.0    7.5  ...   80.0         109.5
# 4       5.0          5.0  59.5     53.0    7.5  ...   21.0         109.5
# ..      ...          ...   ...      ...    ...  ...    ...           ...
# 125   126.0        125.0  59.5     53.0   23.0  ...   21.0          87.0
# 126   127.0        126.0  59.5     91.0  118.5  ...   21.0          38.0
# 127   128.0        127.0  59.5     53.0   79.0  ...   72.0         109.5
# 128   129.0        128.0  59.5     53.0   91.5  ...   74.0          38.0
# 129   130.0        129.0  59.5    117.5   23.0  ...  118.0          38.0
#
#      BASE_PRICE  SOLD_PRICE  PREMIUM
# 0           9.0         5.5     16.5
# ...

# %%
df.values
# Out:
# array([[1, 'Abdulla, YA', 2, ..., 50000, 50000, 0],
#        [2, 'Abdur Razzak', 2, ..., 50000, 50000, 0],
#        [3, 'Agarkar, AB', 2, ..., 200000, 350000, 150000],
#        ...,
#        [128, 'Yuvraj Singh', 2, ..., 400000, 1800000, 1400000],
#        [129, 'Zaheer Khan', 2, ..., 200000, 450000, 250000],
#        [130, 'Zoysa, DNT', 2, ..., 100000, 110000, 10000]], dtype=object)

# %%
df['COUNTRY'].apply('I am a {}'.format)
# Out:
# 0       I am a SA
# 1      I am a BAN
# 2      I am a IND
# 3      I am a IND
# 4      I am a IND
#           ...
# 125    I am a IND
# 126    I am a PAK
# 127    I am a IND
# 128    I am a IND
# 129     I am a SL
# Name: COUNTRY, Length: 130, dtype: object

# %%
df.isnull()
df.notnull()
# Out:
#      SL.NO.  PLAYER_NAME    AGE  COUNTRY   TEAM  ...  SR-BL  AUCTION_YEAR  \
# 0     False        False  False    False  False  ...  False         False
# 1     False        False  False    False  False  ...  False         False
# 2     False        False  False    False  False  ...  False         False
# 3     False        False  False    False  False  ...  False         False
# 4     False        False  False    False  False  ...  False         False
# ..      ...          ...    ...      ...    ...  ...    ...           ...
# 125   False        False  False    False  False  ...  False         False
# 126   False        False  False    False  False  ...  False         False
# 127   False        False  False    False  False  ...  False         False
# 128   False        False  False    False  False  ...  False         False
# 129   False        False  False    False  False  ...  False         False
#
#      BASE_PRICE  SOLD_PRICE  PREMIUM
# 0         False       False    False
# ...

# %% [markdown]
# # Missing values
# ## dataset 2: auto+mpg

# %%
data = "D:\\01\\Machine_Learning_DineshKumar_book\\Data\\auto-mpg.data"
autos = pd.read_csv(data, sep = '\s+', header = None)
autos.head()
# Out:
#       0  1      2      3       4     5   6  7                          8
# 0  18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1  15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2  18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3  16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4  17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino

# %%
s1 = """mpg
cylinders
displacement
horsepower
weight
acceleration
model_year
origin

car_name
"""
[s for s in s1.split()]
# Out:
# ['mpg',
#  'cylinders',
#  'displacement',
#  'horsepower',
#  'weight',
#  'acceleration',
#  'model_year',
#  'origin',
#  'car_name']

# %%
autos.columns = [s for s in s1.split()]
autos.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                   car_name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
autos.info()
autos.nunique()
autos.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car_name      398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB
# mpg             129
# cylinders         5
# displacement     82
# horsepower       94
# weight          351
# acceleration     95
# model_year       13
# origin            3
# car_name        305
# dtype: int64
#               mpg   cylinders  displacement       weight  acceleration  \
# ...

# %%
autos["horsepower"] = pd.to_numeric(autos["horsepower"], errors ="coerce")

# %%
mask = autos["horsepower"].isnull()
autos[mask]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32   25.0          4          98.0         NaN  2046.0          19.0
# 126  21.0          6         200.0         NaN  2875.0          17.0
# 330  40.9          4          85.0         NaN  1835.0          17.3
# 336  23.6          4         140.0         NaN  2905.0          14.3
# 354  34.5          4         100.0         NaN  2320.0          15.8
# 374  23.0          4         151.0         NaN  3035.0          20.5
#
#      model_year  origin              car_name
# 32           71       1            ford pinto
# 126          74       1         ford maverick
# 330          80       2  renault lecar deluxe
# 336          80       1    ford mustang cobra
# 354          81       2           renault 18i
# 374          82       1        amc concord dl

# %%
autos.dropna(subset = ["horsepower"], inplace = True)

# %%
mask = autos["horsepower"].isnull()
autos[mask]
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, model_year, origin, car_name]
# Index: []

# %%
col_numerical = autos.describe().columns.tolist()
col_numerical
col_categorical = [col for col in autos.columns.tolist() if col not in col_numerical]
col_categorical
# Out:
# ['mpg',
#  'cylinders',
#  'displacement',
#  'horsepower',
#  'weight',
#  'acceleration',
#  'model_year',
#  'origin']
# ['car_name']

# %%
autos.info()
autos.head()
autos.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    float64
#  5   acceleration  392 non-null    float64
#  6   model_year    392 non-null    int64
#  7   origin        392 non-null    int64
#  8   car_name      392 non-null    object
# dtypes: float64(5), int64(3), object(1)
# memory usage: 30.6+ KB
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# ...

# %%
autos["cylinders"].plot(kind = "hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.boxplot(x= "cylinders", y = "mpg", data = autos)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='mpg'>

# %%
tips_df = sns.load_dataset("tips")
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_df["size"].plot(kind= "hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.hist(tips_df["size"])
# Out:
# (array([  4.,   0., 156.,   0.,  38.,   0.,  37.,   0.,   5.,   4.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.countplot(x ="size", data = tips_df)
# Out:
# <AxesSubplot:xlabel='size', ylabel='count'>

# %%
sns.barplot(x ="sex", y ="total_bill", data = tips_df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
# sns.barplot(x ="sex", y ="total_bill", data = tips_df, estimator = np.mean)
sns.barplot(x ="sex", y ="total_bill", data = tips_df, estimator = np.mean, hue = "smoker")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x ="sex", y ="total_bill", data = tips_df, estimator = np.sum)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(x ="size", data = tips_df)
# Out:
# <AxesSubplot:xlabel='size', ylabel='count'>

# %%
sns.boxplot(x="day", y="total_bill", hue="sex",data=tips_df, palette="coolwarm")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", data=tips_df, hue='sex',palette='Set1')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", data=tips_df,hue='sex',split=True,palette='Set1')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="total_bill", data=tips_df,jitter=True,hue='sex',palette='Set1',dodge=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day", y="total_bill", data=tips_df, hue = 'sex', dodge=False, color = 'red')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.heatmap(tips_df.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>
