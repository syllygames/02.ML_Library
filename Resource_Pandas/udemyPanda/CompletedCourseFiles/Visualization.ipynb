# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd
from pandas_datareader import data

import matplotlib.pyplot as plt
# following to make output inside notebook.
# cell magic or line magic.
# %matplotlib inline

# %% [markdown]
# ## The `.plot() ` Method

# %%
bb = data.DataReader(name = "MSFT", data_source = "yahoo", start = "2007-07-01", end = "2008-12-31")
bb.head(3)
# Out:
#                  High        Low       Open  Close      Volume  Adj Close
# Date
# 2007-07-02  29.799999  29.490000  29.670000  29.74  47316000.0  22.129314
# 2007-07-03  30.219999  29.780001  29.790001  30.02  35202600.0  22.337667
# 2007-07-05  30.219999  29.830000  30.049999  29.99  47838500.0  22.315336

# %%
# Calling the plot in entire dartaframe as a whole.

type(bb)
bb.plot(y = "High")
bb.plot()
# Out:
# pandas.core.frame.DataFrame
# <AxesSubplot:xlabel='Date'>
# <AxesSubplot:xlabel='Date'>

# %%
bb["Close"]
# Out:
# Date
# 2007-07-02    29.740000
# 2007-07-03    30.020000
# 2007-07-05    29.990000
# 2007-07-06    29.969999
# 2007-07-09    29.870001
#                 ...
# 2008-12-24    19.170000
# 2008-12-26    19.129999
# 2008-12-29    18.959999
# 2008-12-30    19.340000
# 2008-12-31    19.440001
# Name: Close, Length: 380, dtype: float64

# %%
# Calling plot() on a specific series or partial dataframe.
bb["Close"].plot()
bb[["High", "Low"]].plot()
bb.plot(y = ["High", "Low"])
# Out:
# <AxesSubplot:xlabel='Date'>
# <AxesSubplot:xlabel='Date'>
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Modifying Aesthetics

# %%
bb = data.DataReader(name = "MSFT", data_source = "yahoo", start = "2007-07-01", end = "2008-12-31")
bb.head(3)
# Out:
#                  High        Low       Open  Close      Volume  Adj Close
# Date
# 2007-07-02  29.799999  29.490000  29.670000  29.74  47316000.0  22.129314
# 2007-07-03  30.219999  29.780001  29.790001  30.02  35202600.0  22.337667
# 2007-07-05  30.219999  29.830000  30.049999  29.99  47838500.0  22.315336

# %%
# list of available templates.
lst = list(plt.style.available)
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# changes setting for entire notebook
plt.style.use("seaborn")

bb.plot(y = "Close")
bb[["High", "Low"]].plot()
(bb["High"] - bb["Low"]).plot()
# Out:
# <AxesSubplot:xlabel='Date'>
# <AxesSubplot:xlabel='Date'>
# <AxesSubplot:xlabel='Date'>

# %%
plt.style.use("dark_background")
bb.plot(y = "Close")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.style.use("ggplot")
bb.plot(y = "Close")
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Bar Charts

# %%
google = data.DataReader(name = "GOOG", data_source = "yahoo", start = "2004-01-01", end = "2016-12-31")
google.head(3)
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2004-08-19  51.835709  47.800831  49.813286  49.982655  44871300.0  49.982655
# 2004-08-20  54.336334  50.062355  50.316402  53.952770  22942800.0  53.952770
# 2004-08-23  56.528118  54.321388  55.168217  54.495735  18342800.0  54.495735

# %%
def rank_performance(stock_price):
    if stock_price <= 200:
        return "Poor"
    elif stock_price > 200 and stock_price <= 500:
        return "Satisfactory"
    else:
        return "Stellar"
# Out:
# Date
# 2004-08-19       Poor
# 2004-08-20       Poor
# 2004-08-23       Poor
# 2004-08-24       Poor
# 2004-08-25       Poor
#                ...
# 2016-12-23    Stellar
# 2016-12-27    Stellar
# 2016-12-28    Stellar
# 2016-12-29    Stellar
# 2016-12-30    Stellar
# Name: Close, Length: 3115, dtype: object

# %%
#  Use of value_counts()
plt.style.use("ggplot")
# google["Close"].apply(rank_performance).value_counts().plot()
# google["Close"].apply(rank_performance).value_counts().plot(kind = "bar")
google["Close"].apply(rank_performance).value_counts().plot(kind = "barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Pie Charts

# %%
apple = data.DataReader(name = "AAPL", data_source = "yahoo", start = "2012-01-01", end = "2016-12-31")
apple.head(3)
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2012-01-03  14.732142  14.607142  14.621428  14.686786  302220800.0  12.691425
# 2012-01-04  14.810000  14.617143  14.642858  14.765715  260022000.0  12.759631
# 2012-01-05  14.948215  14.738214  14.819643  14.929643  271269600.0  12.901293

# %%
apple["Close"].mean()
# Out:
# 23.34042980636815

# %%
def rank_performance(stock_price):
    if stock_price >= 92.63809405940599:
        return "Above Average"
    else:
        return "Below Average"

# %%
plt.style.use("ggplot")
apple["Close"].apply(rank_performance).value_counts().plot(kind = "pie", legend = True)
# Out:
# <AxesSubplot:ylabel='Close'>

# %% [markdown]
# ## Histograms

# %%
google = data.DataReader(name = "GOOG", data_source = "yahoo", start = "2004-01-01", end = "2016-12-31")
google.head(3)
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2004-08-19  51.835709  47.800831  49.813286  49.982655  44871300.0  49.982655
# 2004-08-20  54.336334  50.062355  50.316402  53.952770  22942800.0  53.952770
# 2004-08-23  56.528118  54.321388  55.168217  54.495735  18342800.0  54.495735

# %%
def custom_round(stock_price):
    return int(stock_price / 100.0) * 100

# %%
custom_round(523)
# Out:
# 500

# %%
google["High"].apply(custom_round).value_counts().sort_index()
# Out:
# 0       159
# 100     414
# 200    1132
# 300     447
# 400     157
# 500     415
# 600     106
# 700     273
# 800      12
# Name: High, dtype: int64

# %%
google["High"].apply(custom_round).nunique()
# Out:
# 9

# %%
google["High"].apply(custom_round).plot(kind = "hist")
google.plot(kind = "hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>
# <AxesSubplot:ylabel='Frequency'>

# %%
google["High"].apply(custom_round).plot(kind = "hist", bins =9)
# Out:
# <AxesSubplot:ylabel='Frequency'>
